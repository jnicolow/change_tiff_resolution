# %% [markdown]
# # Batch upsample site TIFFs (bilinear + bicubic)
#
# Runs `convert_site_tiffs.convert_sites_to_higher_resolution`, which mirrors the workflow in `change_tiff_res_test.ipynb`: discover all `.tif` / `.tiff` files under each site folder, upsample by an integer scale factor, and write outputs to **`data/sat_images/<site>/<bilinear|bicubic>/...`** (relative subfolders preserved).
#
# **Set the working directory to this repo root** (`change_tiff_resolution`) before running, or adjust `PROJECT_ROOT` below.

# %%
import sys
from pathlib import Path

try:
    PROJECT_ROOT = Path(__file__).resolve().parent
except NameError:
    PROJECT_ROOT = Path.cwd()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from change_tiff_res.convert_site_tiffs import convert_sites_to_higher_resolution

# %%
import os

# Parent folder that contains one subfolder per site (same layout as change_tiff_res_test.ipynb).
source_dir = Path(
    os.path.join(
        os.path.dirname(os.getcwd()),
        "SDS_performance_analysis",
        "data",
        "sat_images",
    )
)

# Folder names under source_dir (e.g. "californiatorreypines").
site_names = [
    "australianarrabeen",
    "australiastocktonbeach",
    "australiabyronbay",
    "australiamonavale",
    "californiatorreypines",
    "northcarolinaduck",
    "francetrucvert",
    "hawaiiwaikiki",
    "alaskabarterisland",
    "massachusettscapecod",
    "floridamadeirabeach"
]

upsample_scale = 2

# Default: PROJECT_ROOT / "data" / "sat_images"
output_root = PROJECT_ROOT / "data" / "sat_images"

print("source_dir:", source_dir)
print(f'{site_names=}')
print("output_root:", output_root.resolve())
# Out:
# source_dir: c:\Users\jnicolow\Documents\research\CRC\SDS_performance_analysis\data\sat_images
# site_names=['australianarrabeen', 'australiastocktonbeach', 'australiabyronbay', 'australiamonavale', 'californiatorreypines', 'northcarolinaduck', 'francetrucvert', 'hawaiiwaikiki', 'alaskabarterisland', 'massachusettscapecod', 'floridamadeirabeach']
# output_root: C:\Users\jnicolow\Documents\research\CRC\change_tiff_resolution\data\sat_images

# %%
written = convert_sites_to_higher_resolution(
    source_dir,
    site_names,
    output_root=output_root,
    upsample_scale=upsample_scale,
    techniques=("bilinear", "bicubic"),
)

print(f"Wrote {len(written)} file(s).")
for p in written[:20]:
    print(p)
if len(written) > 20:
    print("...")
# Out:
# C:\Users\jnicolow\AppData\Local\Temp\ipykernel_19952\3663207736.py:1: UserWarning: Skipping missing site directory: c:\Users\jnicolow\Documents\research\CRC\SDS_performance_analysis\data\sat_images\australiastocktonbeach
#   written = convert_sites_to_higher_resolution(
# C:\Users\jnicolow\AppData\Local\Temp\ipykernel_19952\3663207736.py:1: UserWarning: No TIFF files under c:\Users\jnicolow\Documents\research\CRC\SDS_performance_analysis\data\sat_images\australiabyronbay
#   written = convert_sites_to_higher_resolution(
# C:\Users\jnicolow\AppData\Local\Temp\ipykernel_19952\3663207736.py:1: UserWarning: Skipping missing site directory: c:\Users\jnicolow\Documents\research\CRC\SDS_performance_analysis\data\sat_images\australiamonavale
#   written = convert_sites_to_higher_resolution(
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 written = convert_sites_to_higher_resolution(
#       2     source_dir,
#       3     site_names,
#       4     output_root=output_root,
#       5     upsample_scale=upsample_scale,
#       6     techniques=("bilinear", "bicubic"),
#       7 )
#       9 print(f"Wrote {len(written)} file(s).")
#      10 for p in written[:20]:
#
# File c:\Users\jnicolow\Documents\research\CRC\change_tiff_resolution\change_tiff_res\convert_site_tiffs.py:90, in convert_sites_to_higher_resolution(source_dir, site_names, output_root, upsample_scale, techniques)
#      88                 raise ValueError("technique must be 'bilinear' or 'bicubic'.")
#      89             out_path = output_root / site / technique / rel
# ---> 90             resample_tiff(
#      91                 tiff_path=tiff_path,
#      92                 desired_resolution=desired,
#      93                 technique=technique,
#      94                 save_path=out_path,
#      95             )
#      96             written.append(out_path)
#      98 return written
#
# File c:\Users\jnicolow\Documents\research\CRC\change_tiff_resolution\change_tiff_res\resample_tiff.py:78, in resample_tiff(tiff_path, desired_resolution, technique, save_path)
#      71 profile = src.profile.copy()
#      72 profile.update(
#      73     height=target_h,
#      74     width=target_w,
#      75     transform=transform,
#      76 )
# ---> 78 with rasterio.open(save_path, "w", **profile) as dst:
#      79     dst.write(resampled)
#      80     # Preserve dataset-level metadata and per-band naming/tags from source.
#
# File c:\Users\jnicolow\AppData\Local\miniconda3\envs\geo_tide\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\jnicolow\AppData\Local\miniconda3\envs\geo_tide\Lib\site-packages\rasterio\__init__.py:366, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     364 writer = get_writer_for_driver(driver)
#     365 if writer is not None:
# --> 366     dataset = writer(
#     367         path,
#     368         mode,
#     369         driver=driver,
#     370         width=width,
#     371         height=height,
#     372         count=count,
#     373         crs=crs,
#     374         transform=transform,
#     375         dtype=dtype,
#     376         nodata=nodata,
#     377         sharing=sharing,
#     378         **kwargs
#     379     )
#     380 else:
#     381     raise DriverCapabilityError(
#     382         "Writer does not exist for driver: %s" % str(driver)
#     383     )
#
# File rasterio\\_io.pyx:1509, in rasterio._io.DatasetWriterBase.__init__()
#
# File rasterio\\_io.pyx:322, in rasterio._io._delete_dataset_if_exists()
#
# File rasterio\\_err.pyx:289, in rasterio._err.exc_wrap_int()
#
# CPLE_AppDefinedError: Deleting c:\Users\jnicolow\Documents\research\CRC\change_tiff_resolution\data\sat_images\californiatorreypines\bilinear\L5\L5_20010505_040037.tif failed: Permission denied
